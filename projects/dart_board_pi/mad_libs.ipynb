# %% [markdown]
# # The Zany Mad Libs!
# ![madlibs.png](attachment:d25eadfb-745e-4db7-8eae-71e1bde94489.png)

# %% [markdown]
# Remember the days when you used to solve crosswords and play Sudoku or Tic-Tac-Toe with your friends instead of online gaming? One such popular party games are the Mad Libs books. From popular references in TV shows such as Friends and The Tonight Show Starring Jimmy Fallon, everyone loves and enjoys Mad Libs.
#
# But, how do you play Mad Libs?

# %% [markdown]
# ## What is Mad Libs ??

# %% [markdown]
# Mad Libs is a game created by Leonard Stern and Roger Price. It is a very popular template word game where one player acts as the reader. They ask the other players, who have no knowledge of the story, to fill in the blanks by choosing adjectives, nouns, verbs, etc. The result is a funny stupid story the players have fun reading and laughing over.
#
# More than 180 Mad Libs with different short stories are available worldwide. Mad Libs is also adapted and made into storylines for many cartoons and shows. These include The Big Bang Theory, The Incredibles, The Office, The Powerpuff Girls, Toy Story, and Angry Birds.

# %% [markdown]
# ### We will build our own Post-Cascade Mad Libs game using Python!

# %%
import textwrap
adjective = input("Enter a adjective or <enter> for default: ") or "crazy"
adjective2 = input("Enter a another adjective or <enter> for default: ") or "blue"
noun = input("Enter a noun or <enter> for default: ") or "trash can"
noun2 = input("Enter another noun or <enter> for default: ") or "clock"
plural_noun = input("Enter a plural noun or <enter> for default: ") or "birds"
game = input("Enter a name of a game or <enter> for default: ") or "ping pong"
plural_noun2 = input("Enter another plural noun or <enter> for default: ") or "snakes"
ing_verb = input("Enter a verb ending in -ing or <enter> for default: ") or "seething"
ing_verb2 = input("Enter another verb ending in -ing or <enter> for default: ") or "tasting"
plural_noun3 = input("Enter a 3rd plural noun or <enter> for default: ") or "dollars"
ing_verb3 = input("Enter a 3rd verb ending in -ing or <enter> for default: ") or "breaking"
noun3 = input("Enter a 3rd noun or <enter> for default: ") or "giraffe"
plant = input("Enter a name of a plant or <enter> for default: ") or "tomato"
body_part = input("Enter the name of a body part (decent ones please ..) or <enter> for default: ") or "elbow"
place = input("Enter a name of a place or <enter> for default: ") or "park"
ing_verb4 = input("Enter a 4th verb ending in -ing or <enter> for default: ") or "sleeping"
adjective3 = input("Enter a 3rd adjective or <enter> for default: ") or "lazy"
number = input("Enter a number or <enter> for default: ") or "9"
plural_noun4 = input("and lastly, Enter a 4th plural noun or <enter> for default: ") or "pencils"
print("click in the next cell and press <shift><enter>")
# Out:
# Enter a adjective or <enter> for default:
# Enter a another adjective or <enter> for default:
# Enter a noun or <enter> for default:
# Enter another noun or <enter> for default:
# Enter a plural noun or <enter> for default:
# Enter a name of a game or <enter> for default:
# Enter another plural noun or <enter> for default:
# Enter a verb ending in -ing or <enter> for default:
# Enter another verb ending in -ing or <enter> for default:
# Enter a 3rd plural noun or <enter> for default:
# Enter a 3rd verb ending in -ing or <enter> for default:
# Enter a 3rd noun or <enter> for default:
# Enter a name of a plant or <enter> for default:
# Enter the name of a body part (decent ones please ..) or <enter> for default:
# Enter a name of a place or <enter> for default:
# Enter a 4th verb ending in -ing or <enter> for default:
# Enter a 3rd adjective or <enter> for default:
# Enter a number or <enter> for default:
# and lastly, Enter a 4th plural noun or <enter> for default:
# ...

# %%
story = ("On our cascade, we took a trip to some " + adjective + " place with our " +
adjective2 + " friends. It is always nice take a field trip that is near a " + noun + " or up on a "+
noun2 + ". A good place to go is where you can explore " + plural_noun + " or learn about " + game
+ " or go looking for " + plural_noun2 + ". I like to spend my time "+ ing_verb + " or " + ing_verb2
+". It reminded me of our last family vacation, where my parents spent their time eating three "+ plural_noun3 +
" a day, and played golf, and we sat around " + ing_verb3
+ ". My little brother fell in a " + noun3 + " and got poison " + plant
+ " all over his " + body_part + ". My family is going to go to the " + place
+ ", and I will practice " + ing_verb4 +
". Parents need these lame vacations as they are always very " + 
adjective3 + " and because they have to work " + number
+ " hours every day all year making enough " + plural_noun4 + " to pay for it all. Me? I'd rather go on a " + adjective + " cascade with my "+
adjective2 + " friends. ")

# %%
print(textwrap.fill(story, 60))
# Out:
# On our cascade, we took a trip to some crazy place with our
# blue friends. It is always nice take a field trip that is
# near a trash can or up on a clock. A good place to go is
# where you can explore birds or learn about ping pong or go
# looking for snakes. I like to spend my time seething or
# tasting. It reminded me of our last family vacation, where
# my parents spent their time eating three dollars a day, and
# played golf, and we sat around breaking. My little brother
# fell in a giraffe and got poison tomato all over his elbow.
# My family is going to go to the park, and I will practice
# sleeping. Parents need these lame vacations as they are
# always very lazy and because they have to work 9 hours every
# day all year making enough pencils to pay for it all. Me?
# I'd rather go on a crazy cascade with my blue friends.
