# %% [markdown]
# # A Galton Board Simulation

# %% [markdown]
# [The Galton board](https://en.wikipedia.org/wiki/Galton_board), also known as the Galton box or quincunx or bean machine, is a device invented by Sir Francis Galton[1] to demonstrate the central limit theorem, in particular that with sufficient sample size the binomial distribution approximates a normal distribution. Among its applications, it afforded insight into regression to the mean or "reversion to mediocrity".

# %% [markdown]
# ## References
# 1. [Permutations & Combinations](https://www.mathsisfun.com/combinatorics/combinations-permutations.html)
# 1. [Galton Board](https://www.mathsisfun.com/data/quincunx-explained.html)
# 1. [Pascals Triangle](https://www.mathsisfun.com/pascals-triangle.html)

# %% [markdown]
# ![gboard2.png](attachment:172ad14e-ac8f-4b9a-a59c-2a2b45b4603b.png)

# %% [markdown]
# ## Task A. Building the Galton Board
# 1. We will divide into the usual 4 teams we have formed.
# 1. Appoint a team leader who will carefully check off each item such that it is completed properly.
# 1. Carefully study the picture above and every team member will create a dot pattern in your field notebook with plain dots (empty holes) and circled dots (holes with dowels).
# 1. If you have properly studied the pattern in the image above, you will notice that 2 dowels are missing where it should be. Put the missing dowels in too. In total, you will install (11! +2) dowels.
# 1. Copy-paste the factorial code from the last class in a new code cell below to show the calculation.
# 1. Take a picture of your own drawing and add to your Jupyter notebook.
# 1. The team will then build the Galton board with supplied materials **EXACTLY** like your notes.
# 1. Everyone will participate in this exercise except the team leader who will monitor the accuracy of the build per the instruction.
# 1. Insert each dowel about 1/3rd of the way in. Orient the supplied peg board **horizontally**.
# 1. At this point ask Chandru to validate the build.
# 1. **Task A is complete!!**

# %% [markdown]
# ## What else can you learn from the Galton Board?

# %% [markdown]
# The Galton Board allows us to explore Pascal's Triangle which the gateway to many wonders of mathematics in the natural world.
#
# * Pascal's Triangle
# * Fibonacci Numbers
# * Binomial Coefficients
# * Many more ...
